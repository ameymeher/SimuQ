# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate some example data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2.5, 3.7, 4.2, 5.0, 5.8])

# Choose the degree of the polynomial (e.g., 2 for quadratic, 3 for cubic, etc.)
degree = 1

# Use numpy.polyfit to fit the polynomial to the data
coefficients = np.polyfit(x, y, degree)

# Create a polynomial function using the coefficients
polynomial_fit = np.poly1d(coefficients)

# Generate a range of x values for plotting the fitted polynomial curve
x_fit = np.linspace(min(x), max(x), 100)

# Create a scatter plot of the data points
plt.scatter(x, y, label='Data Points')

# Add the polynomial fit curve to the plot
plt.plot(x_fit, polynomial_fit(x_fit), color='red', label='Polynomial Fit')

# Display the plot
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Polynomial Fit Example')
plt.legend()
plt.show()
