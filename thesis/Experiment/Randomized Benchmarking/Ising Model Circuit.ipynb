# %%
import numpy as np
from hamiltonian_models import Ising

# %%
N = 4
T = 1

# %% [markdown]
# ### Ising chain model creation

# %%
h = np.array([1 for j in range(N)])
J_chain = np.zeros((N, N))
for j in range(N - 1):
    J_chain[j, j + 1] = 1

J_cycle = np.copy(J_chain)
J_cycle[0, N - 1] = 1

Ising_chain = Ising(N, T, J_chain, h)

# %% [markdown]
# ### Initialization step

# %%
from qiskit_ibm_provider import IBMProvider
from simuq.provider import BaseProvider
from simuq.solver import generate_as

# %%
#Init parameters of the IBMProvider
qs = Ising_chain
hub = "ibm-q-ncsu"
group = "nc-state"
project = "quantum-compiler"
api_file = "../../ibm_API_key"
aais = 'heisenberg'
backend = 'ibmq_mumbai'
tol = 0.01
trotter_num = 6
verbose = 0
use_pulse = True
state_prep = None

# %%
#Init functionality of the IBMProvider
from qiskit_ibm_provider import IBMProvider
with open(api_file, "r") as f:
        api_key = f.readline().strip()

provider = IBMProvider(api_key, instance='ibm-q-ncsu/nc-state/quantum-compiler')

# %% [markdown]
# ### Compilation step

# %%
backend = provider.get_backend(backend)
nsite = backend.configuration().n_qubits

if qs.num_sites > nsite:
    raise Exception("Device has less sites than the target quantum system.")

if aais == "heisenberg":
    import ibm
    from qiskit_pulse_ibm import transpile

    mach = ibm.generate_qmachine(backend)
    comp = transpile

# %%
layout, sol_gvars, boxes, edges = generate_as(
    qs,
    mach,
    trotter_num,
    solver="least_squares",
    solver_args={"tol": tol},
    override_layout=None,
    verbose=verbose,
)

# %%
circ = []

for i in range(6):
    circ.append(comp(
        backend,
        layout,
        sol_gvars,
        boxes,
        edges,
        use_pulse=True,
        noise_factor=i
    ))

# %%
circ[0].draw('mpl',idle_wires=False)

# %%
circ[5].count_ops()
# Out:
# OrderedDict([('rz', 528),
#              ('h', 396),
#              ('rx', 264),
#              ('rzx', 198),
#              ('measure', 4),
#              ('barrier', 1)])

# %%
circ[5].depth()
# Out:
# 595

# %%
circ[0].calibrations
# Out:
# {'rzx': {((3, 2),
#    (0.3333333341884255,)): ScheduleBlock(ScheduleBlock(ScheduleBlock(Play(GaussianSquare(duration=256, sigma=64, width=0, amp=0.19572952182664236, angle=-1.9492462558785748), ControlChannel(6)), name="rescale_cr_inst", transform=AlignLeft()), ScheduleBlock(Play(GaussianSquare(duration=256, sigma=64, width=0, amp=0.033952943392330674, angle=-0.028422516217241525), DriveChannel(2)), name="rescale_cr_inst", transform=AlignLeft()), name="block1", transform=AlignLeft()), ScheduleBlock(Play(Drag(duration=160, sigma=40, beta=-0.7976372267881141, amp=0.16173027339239548, angle=0.0, name='Xp_d3'), DriveChannel(3), name='Xp_d3'), name="x", transform=AlignLeft()), ScheduleBlock(ScheduleBlock(Play(GaussianSquare(duration=256, sigma=64, width=0, amp=0.19572952182664236, angle=1.1923463977112183), ControlChannel(6)), name="rescale_cr_inst", transform=AlignLeft()), ScheduleBlock(Play(GaussianSquare(duration=256, sigma=64, width=0, amp=0.033952943392330674, angle=3.1131701373725518), DriveChannel(2)), name="rescale_cr_inst", transform=AlignLeft()), name="block4", transform=AlignLeft()), ScheduleBlock(Play(Drag(duration=160, sigma=40, beta=-0.7976372267881141, amp=0.16173027339239548, angle=0.0, name='Xp_d3'), DriveChannel(3), name='Xp_d3'), name="x", transform=AlignLeft()), name="rzx(0.333)", transform=AlignSequential()),
#   ((0, 1),
#    (0.33333333198024556,)): ScheduleBlock(ScheduleBlock(ScheduleBlock(Play(GaussianSquare(duration=256, sigma=64, width=0, amp=0.19709474275293654, angle=1.7208641035445162), ControlChannel(0)), name="rescale_cr_inst", transform=AlignLeft()), ScheduleBlock(Play(GaussianSquare(duration=256, sigma=64, width=0, amp=0.034029575099950235, angle=-0.009164190686626886), DriveChannel(1)), name="rescale_cr_inst", transform=AlignLeft()), name="block8", transform=AlignLeft()), ScheduleBlock(Play(Drag(duration=160, sigma=40, beta=-0.42034176917492766, amp=0.16289214304687627, angle=0.0, name='Xp_d0'), DriveChannel(0), name='Xp_d0'), name="x", transform=AlignLeft()), ScheduleBlock(ScheduleBlock(Play(GaussianSquare(duration=256, sigma=64, width=0, amp=0.1970947427529365, angle=-1.420728550045277), ControlChannel(0)), name="rescale_cr_inst", transform=AlignLeft()), ScheduleBlock(Play(GaussianSquare(duration=256, sigma=64, width=0, amp=0.034029575099950235, angle=3.132428462903166), DriveChannel(1)), name="rescale_cr_inst", transform=AlignLeft()), name="block11", transform=AlignLeft()), ScheduleBlock(Play(Drag(duration=160, sigma=40, beta=-0.42034176917492766, amp=0.16289214304687627, angle=0.0, name='Xp_d0'), DriveChannel(0), name='Xp_d0'), name="x", transform=AlignLeft()), name="rzx(0.333)", transform=AlignSequential()),
#   ((2, 1),
#    (0.3333333341884254,)): ScheduleBlock(ScheduleBlock(ScheduleBlock(Play(GaussianSquare(duration=384, sigma=64, width=121.47616573125282, amp=0.5398217931483035, angle=2.6401538083526663), ControlChannel(4)), name="rescale_cr_inst", transform=AlignLeft()), ScheduleBlock(Play(GaussianSquare(duration=384, sigma=64, width=121.47616573125282, amp=0.019260568367836652, angle=0.011053008892427087), DriveChannel(1)), name="rescale_cr_inst", transform=AlignLeft()), name="block15", transform=AlignLeft()), ScheduleBlock(Play(Drag(duration=160, sigma=40, beta=0.7028356577829699, amp=0.16400450119441687, angle=0.0, name='Xp_d2'), DriveChannel(2), name='Xp_d2'), name="x", transform=AlignLeft()), ScheduleBlock(ScheduleBlock(Play(GaussianSquare(duration=384, sigma=64, width=121.47616573125282, amp=0.5398217931483035, angle=-0.5014388452371271), ControlChannel(4)), name="rescale_cr_inst", transform=AlignLeft()), ScheduleBlock(Play(GaussianSquare(duration=384, sigma=64, width=121.47616573125282, amp=0.019260568367836652, angle=-3.1305396446973663), DriveChannel(1)), name="rescale_cr_inst", transform=AlignLeft()), name="block18", transform=AlignLeft()), ScheduleBlock(Play(Drag(duration=160, sigma=40, beta=0.7028356577829699, amp=0.16400450119441687, angle=0.0, name='Xp_d2'), DriveChannel(2), name='Xp_d2'), name="x", transform=AlignLeft()), name="rzx(0.333)", transform=AlignSequential())},
#  'rx': {((0,),
#    (0.3333333341884256,)): ScheduleBlock(Play(Drag(duration=160, sigma=40, beta=-0.3353843608100455, amp=0.017367282566588607, angle=0), DriveChannel(0)), name="rx(%.3f)", transform=AlignLeft()),
#   ((3,),
#    (0.33333333418842553,)): ScheduleBlock(Play(Drag(duration=160, sigma=40, beta=-0.867515179472565, amp=0.01726164370076897, angle=0), DriveChannel(3)), name="rx(%.3f)", transform=AlignLeft()),
#   ((1,),
#    (0.33333333418842553,)): ScheduleBlock(Play(Drag(duration=160, sigma=40, beta=-0.9848917232200409, amp=0.01901169517979148, angle=0), DriveChannel(1)), name="rx(%.3f)", transform=AlignLeft()),
#   ((2,),
#    (0.33333333418842553,)): ScheduleBlock(Play(Drag(duration=160, sigma=40, beta=0.760992997462762, amp=0.017442764778340066, angle=0), DriveChannel(2)), name="rx(%.3f)", transform=AlignLeft())}}

# %%
from qiskit import transpile as transpile_qiskit
transpiled_circ = []

for i in range(len(circ)):
    transpiled_circ.append(transpile_qiskit(circ[i],backend))

# %%
transpiled_circ[5].count_ops()
# Out:
# OrderedDict([('rzx', 198),
#              ('rz', 53),
#              ('sx', 30),
#              ('measure', 27),
#              ('barrier', 1)])

# %%
transpiled_circ[5].depth()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/amey/Desktop/Tasks/Thesis/SimuQ/thesis/Experiment/Ising Model ZNE execution/Ising Model Circuit.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/Users/amey/Desktop/Tasks/Thesis/SimuQ/thesis/Experiment/Ising%20Model%20ZNE%20execution/Ising%20Model%20Circuit.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> transpiled_circ[5].depth()
#
# NameError: name 'transpiled_circ' is not defined

# %%
transpiled_circ[0].draw('mpl',idle_wires=False)
# Out:
# C:\Users\Admin\.conda\envs\thesis\lib\site-packages\qiskit\visualization\circuit\matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
from qiskit import execute

job = execute([transpiled_circ[0]] * 5, shots=1024, backend=backend)
print(job.job_id())
# Out:
# cp6036m2zy6g00845v70

# %%
from qiskit import execute
for i in range(len(transpiled_circ)):
    job = execute([transpiled_circ[i]] * 5, shots=1024, backend=backend)
    print(job.job_id())
# Out:
# cnkt0s3takkg008rf7zg
# cnkt0wv7aw9g008gj3cg
# cnkt10ctakkg008rf810
# cnkt11wtpj7000841xcg
# cnkt134tpj7000841xd0
# cnkt14mtpj7000841xdg
